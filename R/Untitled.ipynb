# %%
library(ggplot2)

# Create a plot with extra margin space
p <- ggplot(df, aes(x, y)) +
  geom_point() +
  annotate("text", x = 2.5, y = 8.5, label = "Above the plot") +
  theme(
    plot.margin = unit(c(2, 1, 1, 1), "cm")  # Add extra space at the top of the plot
  ) + scale_y_continuous(limits=c(0, 8)) +
  theme(plot.margin = unit(c(1, 5, 1, 1), "lines")) +
  coord_cartesian(clip = "off")

# Print the plot
print(p)
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_text()`).”
# plot without title
